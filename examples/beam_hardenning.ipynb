# %%
import sys

sys.path.append("/home/s4861264/CIT_project/")
from workflows.beam_hardening_correction.workflow import BeamHardeningCorrectionWorkflow

# %%
workflow = BeamHardeningCorrectionWorkflow(
    optim_steps=100
)

# %%
final_reconstruction, history = workflow.run()
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 final_reconstruction, history = workflow.run()
#
# File ~/CIT_project/workflows/beam_hardening_correction/workflow.py:55, in BeamHardeningCorrectionWorkflow.run(self)
#      52 reconstruct_output = self.Reconstruct.execute(input_data)
#      54 # Optimization loop
# ---> 55 sim_data, history = self._optim_loop(input_data, reconstruct_output)
#      57 correct_projection = self.CorrectProjection.execute(sim_data)
#      59 final_reconstruction = self.Reconstruct.execute(correct_projection)
#
# File ~/CIT_project/workflows/beam_hardening_correction/workflow.py:65, in BeamHardeningCorrectionWorkflow._optim_loop(self, input_data, reconstructed_data)
#      63 history = []
#      64 for _ in range(self._optim_steps):
# ---> 65     A_sim = self.SpectralProjection.execute(reconstructed_data) # (n_angles, n_pixels, n_pixels)
#      66     A_meas = input_data # (n_angles, n_pixels, n_pixels)
#      68     loss = self._loss_fn(A_sim, A_meas)
#
# File ~/CIT_project/workflows/beam_hardening_correction/blocks.py:88, in SpectralProjection.execute(self, reconstruction)
#      87 def execute(self, reconstruction):
# ---> 88     return self.forward(reconstruction)
#
# File ~/CIT_project/workflows/beam_hardening_correction/isp.py:24, in ISP.forward(self, reconstruction)
#      21 def forward(self, reconstruction):
#      22     # Ensure reconstruction is on the same device as the parameters
#      23     reconstruction = reconstruction.to(self._device)
# ---> 24     I_sim = self._compute_I_sim(reconstruction) # (n_angles, n_pixels, n_pixels)
#      25     A_sim = self._compute_A_sim(I_sim) # (n_angles, n_pixels, n_pixels)
#      26     return A_sim
#
# File ~/CIT_project/workflows/beam_hardening_correction/isp.py:80, in ISP._compute_I_sim(self, reconstruction)
#      77 # unsqueeze mu to (energy_bins, number_of_materials, 1, 1, 1) for broadcasting
#      78 mu = mu.unsqueeze(-1).unsqueeze(-1).unsqueeze(-1) # (energy_bins, number_of_materials, 1, 1, 1)
# ---> 80 exponent = torch.sum(mu * As_n, axis=1) # (energy_bins, n_angles, n_pixels, n_pixels)
#      81 exponential = torch.exp(-exponent)
#      83 I = self.I.unsqueeze(-1).unsqueeze(-1).unsqueeze(-1) # (energy_bins, 1, 1, 1)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 7.87 GiB. GPU 0 has a total capacity of 22.03 GiB of which 5.95 GiB is free. Including non-PyTorch memory, this process has 16.08 GiB memory in use. Of the allocated memory 15.85 GiB is allocated by PyTorch, and 15.49 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
